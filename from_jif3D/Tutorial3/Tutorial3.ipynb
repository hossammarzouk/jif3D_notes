# %% [markdown]
# # jif3D Tutorial 3 -- joint inversion with a cross-gradient
#
# Now that we have performed individual inversions with each dataset, we are ready to perform a joint inversion of the two. We will start with the well-established cross-gradient based approach (Gallardo, L. A., & Meju, M. A. (2004). Joint two‐dimensional DC resistivity and seismic travel time inversion with cross‐gradients constraints. Journal of Geophysical Research: Solid Earth, 109(B3)). The cross-gradient aims at making anomalies in the two models look similar in a general sense.
#
# In our example with a density model $\mathbf{m}_{dens}$ and a susceptibility model  $\mathbf{m}_{dens}$ the cross-gradient is defined as
# $$ \Phi_{cg}(\mathbf{m}_{dens}, \mathbf{m}_{sus}) = \left( \nabla \mathbf{m}_{dens} \times \nabla \mathbf{m}_{sus} \right)^2, $$
# where $\nabla$ is the spatial gradient (the variation of values between adjacent model cells) and $\times$ denotes the cross-product (hence the name cross-gradient). We can introduce this term into the objective function and the total quantity to minimize then becomes
# $$ \Phi(\mathbf{m}_{dens}, \mathbf{m}_{sus}) = \lambda_1 \Phi_{grav}(\mathbf{m}_{dens}) +  \lambda_2 \Phi_{mag}(\mathbf{m}_{sus}) + \lambda_3 \Phi_{reg,grav}(\mathbf{m}_{dens}) + \lambda_4 \Phi_{reg,mag}(\mathbf{m}_{sus})
# + \lambda_5 \Phi_{cg}(\mathbf{m}_{dens}, \mathbf{m}_{sus}).$$
#
# So we have two data misfit terms, two regularization terms and the coupling that need to be balanced. Here some of the work we performed during the individual inversions pays out. In my experience the regularization parameters that work best for the individual inversions also work for cross-gradient based inversion. So we can use these as starting values for our joint inversion. In some cases we have to adjust the balance between the different datasets by increasing the weight for one of them. This can be the case if the inversion only works on one dataset and largely neglects the other. In this example this does not seem to be a problem. Therefore the only thing we have to adjust is the coupling between the datasets by adjusting the corresponding weight.
#
# We want to find a model that fits both datasets as well as the individual inversions but has increased structural similarity indicated by a low cross-gradient value.

# %%
import numpy as np
from netCDF4 import Dataset
import matplotlib.pyplot as plt

# %% [markdown]
# ## Running the inversion
# Compared to the individual inversions, running a joint inversion simply means setting the weights for scalar gravity and magnetic to 1, specifying all inversion meshes and data files, setting the two regularization weights and the weight for the cross-gradient. Thus the run script below is only a slight modification from the previous two tutorials.

# %%
#location of the jif3D executables on your system
execpath = "/home/max/workspace/jif3D/bin/"
#program we want to run
progname = "jointinv"
options = " --inclination 1.17 --declination 0.22 --fieldstrength 52671 --vi 0"
#name of the density starting mesh
gravmesh = "../Tutorial1/start_grav.nc"
#name of the gravity data file
gravdata = "../Tutorial1/gravdata.nc"
#name of the susecptibility starting mesh
magmesh = "../Tutorial2/start_mag.nc"
#name of the magnetics data file
magdata = "../Tutorial2/magdata.nc"
#weight for standard gravity data, set to 1
gravweight = 1.0
#weight for the magnetic data, set to 1 as well for joint inversion
magweight = 1.0
#weight for the FTG data, set to zero at the moment as we do not have FTG data 
ftgweight = 0
#so we set the corresponding weights to zero to disable them
magvectorweight = 0.0
mtweight = 0.0
dcweight = 0.0
tomographyweight = 0.0
surfacewaveweight = 0.0
#weight for the density regularization, use value from Tutorial 1
gravregularization = 100.0
#weight for susceptibility regularization, use value from Tutorial 2
magregularization = 100.0
# weight for the coupling term, higher means stronger influence of cross-gradient = more similar models
coupling = 1e9
#maximum number of iterations, CG tends to converge more slowly, so we bump it up again
iterations = 100
#write all information to file
f = open('run', 'w')
f.write(execpath+progname+options+" <<eof \n")    
f.write(magmesh+"\n")
f.write(str(gravweight)+"\n")
f.write(str(ftgweight)+"\n")
f.write(gravdata+"\n")
f.write(gravmesh+"\n")
f.write(str(magweight)+"\n")
f.write(magdata+"\n")
f.write(magmesh+"\n")
f.write(str(magvectorweight)+"\n")
f.write(str(mtweight)+"\n")
f.write(str(dcweight)+"\n")
f.write(str(tomographyweight)+"\n")
f.write(str(surfacewaveweight)+"\n")
f.write(str(coupling)+"\n")
f.write(str(gravregularization)+"\n")
f.write(str(magregularization)+"\n")
f.write(str(iterations)+"\n")
f.write("eof\n")
f.close()

# %% [markdown]
# Once we have specified the type of inversion, the files and weights, running the scripts works exactly as before.

# %%
import subprocess
outfile = open("jif3dcrossout.out",'w')
subprocess.run(["bash ./run", ""],stdout=outfile,shell=True)
outfile.close()
log = open("jif3dcrossout.out",'r')
for line in log:
    print(line)
# Out:
# Mesh filename: Scalar Gravimetry Lambda: FTG Lambda: Scalar Gravity Data Filename: Gravity Model Filename:  Model Z Origin: 0 larger than minimum data z-coordinate: -0.3
#
#  Some scalar gravity data are outside modelling domain, inversion will run but might produce unexpected results !
#
# Storing sensitivities in memory
#
# Storing sensitivities on disk
#
# Scalar gravity will take 0.821821 GB disk space
#
# Scalar Gravity ndata: 836
#
# Scalar Gravity lambda: 1
#
# Setting global covariance for Density
#
# Total field magnetics Lambda: Total field magnetic Data Filename: Susceptibility Model Filename:  Model Z Origin: 0 larger than minimum data z-coordinate: -10000
#
#  Some data are outside modelling domain, inversion will run but might produce unexpected results !
#
# Storing sensitivities in memory
#
# Storing sensitivities on disk
#
# Magnetics will take 2.44777 GB disk space
#
#  Magnetics ndata: 830
#
#  Magnetics lambda: 1
#
# Setting global covariance for Susceptibility
#
# 3-component magnetization Lambda: MT Lambda: DCResistivity Lambda: Tomography Lambda: Surface wave tomography Lambda: Working on segment 0
#
# Assigned inversion parameters for Density, startindex: 0
#
# Working on segment 1
#
# Assigned inversion parameters for Susceptibility, startindex: 122880
#
# CG Density-Susceptibility weight:Density  Regularization Lambda:  Setting up stochastic covariance for segment 0 Density
#
# Index for correlation distance is 9
#
#  Segment start: 0 Segment end: 122880
#
# Susceptibility  Regularization Lambda:  Setting up stochastic covariance for segment 1 Susceptibility
#
# Index for correlation distance is 9
#
#  Segment start: 122880 Segment end: 245760
#
# Maximum number of iterations: Performing inversion.
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     850225                1.20219e+06                          0                          0                          0
#
# Runtimes:
#
#                          8                         21                          0                          0                          0
#
#
#
# Iteration: 0
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     850225                1.20219e+06                          0                          0                          0
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     247471                1.47937e+06                          0                          0                          0
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                4.39988e+06                3.20194e+09                 0.00113839                    1.83005                    173.739
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     790826                9.06887e+07                 0.00144606                    1.19341                    13.3062
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     832740                     834934                3.26967e-13                3.10149e-05                 0.00294445
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     243818                1.15529e+06                1.00889e-10                 0.00491296                   0.054778
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 1
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     731847                     248827                4.02757e-10                 0.00157875                  0.0704368
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     222050                     535870                2.07762e-08                  0.0349385                   0.303341
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 2
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     655312                     166737                2.00129e-09                 0.00469915                   0.116148
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     204765                     444340                6.95587e-08                  0.0600262                   0.425302
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 3
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     469198                     148944                2.54126e-08                  0.0233869                   0.284201
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     158458                     476240                4.86826e-07                   0.133069                   0.747088
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 4
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     290042                     184628                 1.3238e-07                  0.0760145                    0.43441
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                     108864                     609654                1.73229e-06                   0.237382                    1.02329
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 5
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     223345                     131313                2.47886e-07                   0.124449                   0.488001
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    93229.4                     441038                2.83521e-06                   0.301652                    1.14802
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 6
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     191724                    86706.9                 3.1615e-07                   0.162205                   0.468342
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    88045.5                     342649                 3.4341e-06                   0.341871                    1.17253
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 7
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     165209                    63256.9                3.91676e-07                   0.206549                    0.44829
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    84791.8                     289478                4.06572e-06                   0.382486                    1.18934
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 8
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     122380                    75299.4                5.53285e-07                   0.308143                   0.415712
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    78090.7                     405266                5.35968e-06                   0.458581                    1.21268
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 9
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     112302                    40711.7                5.43348e-07                   0.315463                   0.399498
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    71728.7                     231471                5.27941e-06                   0.461918                    1.18897
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 10
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     100947                    32097.1                 5.4652e-07                   0.325828                   0.389978
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    64535.3                     201966                5.28197e-06                   0.466941                    1.17056
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 11
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    75160.6                    34079.9                6.27322e-07                   0.379859                   0.382168
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    51229.2                     222836                5.88179e-06                   0.497847                    1.16868
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 12
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    49410.3                    40124.2                7.98414e-07                   0.474096                   0.388679
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    37929.1                     286230                7.22031e-06                    0.54843                    1.20186
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 13
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    42620.2                    28270.4                9.31126e-07                   0.539764                   0.397804
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    37022.2                     189383                8.24256e-06                   0.582419                    1.23757
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 14
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    41002.7                    19078.5                9.41414e-07                   0.543933                    0.40102
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    34075.4                     144563                8.33466e-06                   0.584929                    1.24485
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 15
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    36704.5                    12473.3                1.01225e-06                   0.570231                   0.414518
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    29301.8                     112645                8.79393e-06                   0.598811                    1.26944
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 16
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    30936.8                    11585.9                1.15328e-06                   0.620084                   0.439841
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    25595.5                     136188                9.56266e-06                   0.624903                    1.30904
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 17
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    29041.8                    8948.16                1.21973e-06                   0.645174                   0.449388
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    25495.2                    93821.9                9.93355e-06                   0.637674                    1.32604
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 18
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                      27820                    7281.29                1.23695e-06                   0.656803                   0.450035
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    24982.3                    77626.1                1.00033e-05                   0.643922                    1.32862
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 19
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    25464.9                    6548.44                1.26861e-06                   0.678255                   0.451493
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    23774.5                      75284                1.01384e-05                   0.655692                    1.33493
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 20
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    20593.6                    7047.11                1.33745e-06                   0.729825                    0.45318
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    20770.8                    96741.1                1.05069e-05                   0.683979                    1.35233
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 21
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    16391.5                    8977.52                1.44916e-06                   0.802176                   0.458692
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    18335.6                     108105                1.11892e-05                   0.722255                     1.3811
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 22
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                      15331                     6687.6                1.45185e-06                   0.816218                   0.456853
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    17057.8                    84672.5                1.12667e-05                   0.730403                    1.38534
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 23
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    13840.2                    4883.83                1.44839e-06                   0.835802                   0.454312
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    15280.1                    68488.6                1.13613e-05                   0.742293                    1.39165
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 24
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    12539.4                     4393.7                1.47252e-06                   0.864053                   0.455953
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    14432.4                      69504                1.16031e-05                   0.758509                    1.40364
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 25
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    11921.5                     3451.5                1.48463e-06                   0.876686                    0.45801
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    14105.1                    53133.3                1.17146e-05                   0.766124                    1.40987
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 26
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    11032.8                    2951.69                1.50189e-06                   0.893419                   0.462082
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    13575.4                    46123.3                1.18613e-05                   0.776622                    1.41943
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 27
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    10200.1                    2851.98                1.51264e-06                    0.90918                   0.465257
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    12996.3                    47581.1                1.19802e-05                   0.786805                    1.42887
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 28
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    8623.33                    3402.49                 1.5356e-06                   0.945653                   0.472329
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                      11867                    59943.3                1.22816e-05                   0.810582                    1.45154
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 29
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    7717.59                    3305.14                1.53956e-06                   0.965964                   0.475943
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    10727.9                    61173.2                1.24139e-05                   0.824843                     1.4655
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 30
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    7311.96                    2629.45                1.53032e-06                   0.971482                   0.476493
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    9942.39                    49281.1                1.23967e-05                   0.829649                     1.4701
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 31
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    6738.72                    2155.36                1.51665e-06                    0.98027                   0.478318
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    8909.28                    42062.4                1.23684e-05                   0.837597                    1.47809
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 32
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    6273.44                    1906.46                1.51086e-06                   0.993016                   0.482319
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    8355.28                    41046.6                1.24047e-05                   0.848054                    1.48878
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 33
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    6012.67                    1574.18                1.50841e-06                    1.00233                    0.48604
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    8136.22                    33268.1                 1.2432e-05                    0.85573                    1.49648
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 34
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    5815.18                    1305.41                1.50462e-06                    1.01007                   0.489313
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7925.37                    27130.1                1.24374e-05                   0.862138                    1.50234
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 35
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    5614.97                     1191.5                1.49604e-06                    1.01773                   0.492179
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7732.83                    25673.9                1.24161e-05                   0.868799                    1.50777
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 36
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    5460.62                    1112.86                1.48565e-06                    1.02293                   0.493668
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7602.96                    23356.2                1.23715e-05                   0.873691                    1.51105
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 37
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    5178.38                    1115.45                1.46074e-06                    1.03163                    0.49506
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7421.34                    25886.5                1.22504e-05                   0.882458                    1.51553
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 38
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    4888.27                    1138.17                1.43314e-06                    1.04143                   0.495646
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7323.76                    29280.7                1.21137e-05                   0.892538                    1.51976
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 39
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    4628.62                    1081.87                1.40689e-06                    1.05134                   0.495788
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7266.45                    28141.7                1.19893e-05                   0.902732                    1.52348
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 40
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    4098.98                     1140.6                1.35158e-06                    1.07805                   0.495876
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    7212.45                    33208.5                1.17747e-05                   0.929805                    1.53315
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 41
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    3885.67                    1026.78                 1.3293e-06                    1.08999                   0.495518
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    6970.55                    30604.8                 1.1702e-05                   0.941901                    1.53702
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 42
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     3838.5                    862.099                 1.3258e-06                    1.08999                   0.495253
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    6722.64                    24454.4                1.16663e-05                   0.942164                    1.53673
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 43
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    3635.33                    768.855                1.30705e-06                    1.09792                   0.495217
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    6232.52                    21917.2                1.15693e-05                   0.950641                    1.53959
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 768.855
#
# Target: 830
#
# Iteration: 44
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     3437.5                    755.199                1.28831e-06                    1.10962                   0.496187
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    5987.53                    22819.8                1.15078e-05                   0.962651                     1.5449
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 755.199
#
# Target: 830
#
# Iteration: 45
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    3075.31                    867.609                1.25728e-06                    1.13795                   0.500384
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    5836.73                    30847.9                1.14658e-05                   0.991416                    1.55956
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Iteration: 46
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    3017.15                     670.08                1.25503e-06                    1.14257                   0.501909
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    5738.22                    22178.4                1.14683e-05                   0.996102                    1.56285
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 670.08
#
# Target: 830
#
# Iteration: 47
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2980.78                    564.574                1.25532e-06                     1.1424                   0.503092
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    5559.39                    18159.6                1.14376e-05                   0.996219                    1.56414
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 564.574
#
# Target: 830
#
# Iteration: 48
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2832.71                    503.765                1.25106e-06                    1.14888                   0.507131
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    5191.96                    17319.9                1.13679e-05                     1.0035                    1.57097
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 503.765
#
# Target: 830
#
# Iteration: 49
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2601.26                    659.428                1.23901e-06                    1.16576                   0.513638
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    4884.89                    29805.8                1.12953e-05                    1.02161                    1.58438
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 659.428
#
# Target: 830
#
# Iteration: 50
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2615.14                    488.376                 1.2387e-06                    1.16447                   0.512882
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    4890.97                    18171.5                1.12906e-05                    1.02024                    1.58308
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 488.376
#
# Target: 830
#
# Iteration: 51
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2576.92                    432.615                1.23432e-06                    1.16844                    0.51353
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    4870.21                    15284.6                 1.1279e-05                    1.02437                    1.58527
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 432.615
#
# Target: 830
#
# Iteration: 52
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    2478.56                    387.533                1.22344e-06                    1.17912                   0.515695
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    4825.17                    13827.6                1.12533e-05                    1.03555                    1.59161
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 387.533
#
# ...
#
#
#
# Individual Grad Norms:
#
#                    3170.43                    10785.7                 9.3348e-06                     1.2038                    1.66002
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 154.242
#
# Target: 830
#
# Iteration: 75
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1228.27                    140.509                8.95697e-07                    1.30972                   0.542339
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3154.69                    9206.39                9.31362e-06                    1.20742                    1.66077
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 140.509
#
# Target: 830
#
# Iteration: 76
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1198.63                    129.226                8.83143e-07                    1.31484                   0.542968
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3130.12                    8643.75                9.28658e-06                    1.21486                    1.66219
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 129.226
#
# Target: 830
#
# Iteration: 77
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1167.75                    129.867                8.69319e-07                    1.32065                   0.543521
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3117.33                     9295.1                9.28564e-06                    1.22319                    1.66373
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 129.867
#
# Target: 830
#
# Iteration: 78
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1088.71                     180.74                8.31891e-07                    1.33901                   0.545037
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3148.93                    15036.9                9.50542e-06                     1.2491                    1.66857
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 180.74
#
# Target: 830
#
# Iteration: 79
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1072.27                    154.911                8.24912e-07                    1.34276                    0.54522
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3122.44                    11473.3                9.58114e-06                    1.25427                    1.66948
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 154.911
#
# Target: 830
#
# Iteration: 80
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1058.37                    140.251                8.20057e-07                    1.34499                   0.545179
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    3049.97                    10217.1                9.62347e-06                     1.2573                    1.66993
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 140.251
#
# Target: 830
#
# Iteration: 81
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    1029.32                    141.176                8.09754e-07                    1.35115                   0.545547
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2937.39                    10483.2                9.78602e-06                    1.26566                    1.67156
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 141.176
#
# Target: 830
#
# Iteration: 82
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    975.525                    137.482                7.92998e-07                    1.36469                   0.547208
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2722.83                    11144.6                1.02778e-05                    1.28377                    1.67589
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 137.482
#
# Target: 830
#
# Iteration: 83
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    935.009                    142.261                 7.7963e-07                    1.37946                   0.549259
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2612.35                    10976.9                1.09728e-05                    1.30326                    1.68089
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 142.261
#
# Target: 830
#
# Iteration: 84
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    932.292                    121.227                7.79519e-07                    1.37968                    0.54962
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2596.71                       9086                1.10011e-05                    1.30349                    1.68132
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 121.227
#
# Target: 830
#
# Iteration: 85
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    922.949                    104.848                7.77341e-07                    1.38207                   0.550519
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2564.69                    7960.43                 1.1169e-05                    1.30652                    1.68281
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 104.848
#
# Target: 830
#
# Iteration: 86
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    909.047                    97.8635                7.73212e-07                    1.38663                   0.551798
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2534.62                     7803.1                1.14946e-05                    1.31236                    1.68521
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 97.8635
#
# Target: 830
#
# Iteration: 87
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     888.34                    95.3582                 7.6621e-07                    1.39468                   0.553838
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2516.38                    8126.14                1.21415e-05                    1.32267                    1.68931
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 95.3582
#
# Target: 830
#
# Iteration: 88
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    881.171                    88.2822                 7.6383e-07                    1.39711                   0.554454
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2506.14                     7278.1                1.23989e-05                     1.3258                    1.69064
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 88.2822
#
# Target: 830
#
# Iteration: 89
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    866.963                    82.8412                7.59711e-07                    1.40145                   0.555652
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2483.03                    7024.66                1.29548e-05                    1.33135                    1.69315
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 82.8412
#
# Target: 830
#
# Iteration: 90
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                     849.43                     81.368                7.55682e-07                    1.40689                   0.557304
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2462.62                    7389.53                1.37662e-05                    1.33832                     1.6964
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 81.368
#
# Target: 830
#
# Iteration: 91
#
# Using previous covariance result
#
# Using previous covariance result
#
#                   ScalGrav                  Magnetics  CG-Density-Susceptibility                 DensityReg          SusceptibilityReg
#
#                    813.602                     90.462                7.49515e-07                    1.41952                   0.561164
#
# Runtimes:
#
#                          0                          0                          0                          0                          0
#
#
#
# Individual Grad Norms:
#
#                    2452.63                    8846.11                1.59344e-05                    1.35458                     1.7039
#
# Runtimes:
#
#                          0                          1                          0                          0                          0
#
#
#
#
#
#
#
# Reached target misfit.
#
# Objective number: 0
#
# Misfit: 813.602
#
# Target: 836
#
# Reached target misfit.
#
# Objective number: 1
#
# Misfit: 90.462
#
# Target: 830
#
# Calculating response of inversion model.
#
# Writing final density models
#
# Writing final susceptibility models

# %% [markdown]
# As before it is useful to look at the development of the different terms of the objective function during the inversion. The *misfit.out* file now has the columns: iteration, gravity misfit, magnetic misfit, gravity regularization, magnetic regularization and cross-gradient term. To make the plots a bit more compact we plot the two data RMS and the model roughness for both data/models together as we want to have a close look at the cross-gradient as well. We can see that the cross-gradient values are much smaller in magnitude compared to everything else. That is one reason why we need to choose a weight to make sure that it participates in the inversion.

# %%
misfit = np.genfromtxt("misfit.out")
rms = np.genfromtxt("rms.out")
plt.figure(figsize=(12,6))
plt.subplot(131)
plt.plot(rms[:,1],label='Gravity')
plt.plot(rms[:,2],label='Magnetics')
plt.legend()
plt.title("RMS")
plt.subplot(132)
plt.plot(misfit[:,5])
plt.plot(misfit[:,6])
plt.title("Model roughness")
plt.subplot(133)
plt.plot(misfit[:,4])
plt.title("Cross-gradient Coupling")
plt.show()

# %% [markdown]
# We compare horizontal slices through the models. At first glance there is no significant difference to the individual inversion results. Without further tests it is unclear though whether this is due to the relatively relaxed similarity criterion defined by the cross-gradient or if the coupling is too weak. This will be one of the tasks to explore in this tutorial.

# %%
#the index of horizontal layer we want to plot, larger numbers = deeper, maximum 29 (nz-1)
depthindex = 10

#read in inversion model
mag_fh = Dataset("result.mag.inv.nc")
Northing =mag_fh.variables["Northing"][:]
Easting =mag_fh.variables["Easting"][:]
Depth =mag_fh.variables["Depth"][:]
Northing_Origin =mag_fh.variables["Northing_Origin"][:]
Easting_Origin =mag_fh.variables["Easting_Origin"][:]
Depth_Origin =mag_fh.variables["Depth_Origin"][:]
invsus = mag_fh.variables["Susceptibility"][:,:,:]
mag_fh.close()

grav_fh = Dataset("result.grav.inv.nc")
invdens = grav_fh.variables["Density"][:,:,:]
grav_fh.close()

pe = np.append(Easting_Origin,Easting)
pn = np.append(Northing_Origin,Northing)
pd = np.append(Depth_Origin,Depth)

plt.figure(figsize = (18,8))
plt.subplot(121)
mx, my = np.meshgrid(pe,pn)
psus = np.transpose(invsus[depthindex,:,:])
plt.pcolormesh(mx,my,psus,vmin=-0.02,vmax=0.02)
plt.title("Susceptibility model at {} km depth".format(Depth[depthindex]))
plt.gca().set_aspect(1)
plt.colorbar()

plt.subplot(122)
pdens = np.transpose(invdens[depthindex,:,:])
plt.pcolormesh(mx,my,pdens,vmin=-50,vmax=50)
plt.title("Density model at {} km depth".format(Depth[depthindex]))
plt.gca().set_aspect(1)
plt.colorbar()
plt.show()

# %% [markdown]
# We also plot two horizontal slices. These confirm our impression that there has been little interaction between the datasets. The two slices do not look particularly similar and the anomalies still extend through large parts of the inversion domain.

# %%
#the index of the East-West slice, larger numbers = further north, maximum 63 (nx-1)
northindex = 32
plt.figure(figsize = (18,8))

plt.subplot(121)
mx, my = np.meshgrid(pe,pd)
plt.pcolormesh(mx,my,invsus[:,:,northindex],vmin=-0.04,vmax=0.04)
plt.ylim([100000,0])
plt.gca().set_aspect(1)

plt.subplot(122)
plt.pcolormesh(mx,my,invdens[:,:,northindex],vmin=-50,vmax=50)
plt.ylim([100000,0])
plt.gca().set_aspect(1)
plt.show()

# %% [markdown]
# It is helpful to investigate where the inversion thinks the models are dissimilar (high cross-gradient value) and where they are considered similar (low cross-gradient value). The program outputs a file *Cross.cg_abs.nc* in the same format as the density model. This contains the cross-gradient constraint value for every model cell. The fact that it reuses the density model format instead of defining its own variable name is half convenience half lazyness. It makes it a bit easier to reuse plotting scripts and alleviates the programmer from coming up with many meaningful names. This lazy approach is used for some other outputs in *jif3D* as well, but might change in the future depending on how problematic this becomes as time goes on.

# %%
#Read in data calculated from the final model
#read in cross-gradient magnitude
cross_fh = Dataset("CG-Density-Susceptibility.cg_abs.nc")
invcross = cross_fh.variables["Density"][:,:,:]
cross_fh.close()

depthindex1 = 0
mx, my = np.meshgrid(pe,pn)

plt.figure(figsize = (18,8))
plt.subplot(121)
pcross = np.transpose(invcross[depthindex1,:,:])
plt.pcolormesh(mx,my,pcross)
plt.title("Cross-gradient magnitude at {} km depth".format(Depth[depthindex1]))
plt.gca().set_aspect(1)
plt.colorbar()
depthindex2 = 10
plt.subplot(122)
pcross = np.transpose(invcross[depthindex2,:,:])
plt.pcolormesh(mx,my,pcross)
plt.title("Cross-gradient magnitude at {} km depth".format(Depth[depthindex2]))
plt.gca().set_aspect(1)
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# In addition to the models itself, the relationship between different parameters is a quantity of interest. For example different geological units should cluster around different values. We therefore make crossplots of density vs. susceptibility for the whole model domain (left) and for the horizontal slices plotted above. There have been examples of successfully extracting such parameter relationships from cross-gradient based inversion(e.g. Moorkamp, M., Roberts, A. W., Jegen, M., Heincke, B., & Hobbs, R. W. (2013). Verification of velocity‐resistivity relationships derived from structural joint inversion with borehole data. Geophysical Research Letters, 40(14), 3596-3601.), however, in this case we cannot really identify distinct units.

# %%
plt.figure(figsize = (8,8))
plt.subplot(121)
plt.scatter(invsus.flatten(),invdens.flatten())
plt.title("Complete model")
plt.xlabel("Susceptibility")
plt.ylabel("Density")
plt.subplot(122)
plt.scatter(psus.flatten(),pdens.flatten())
plt.title("Only horizontal slice")
plt.xlabel("Susceptibility")
plt.show()

# %% [markdown]
# ## Tasks
#
# - Find the maximum cross-gradient weight that still produces a reasonable fit to the data, i.e. comparable to the individual inversions. Increase the original weight by a factor of ten until you deem the fit unsatisfactory
# - Observe what happens to the model and the cross-gradient plots when changing the weight
